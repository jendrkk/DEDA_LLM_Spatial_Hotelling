# %%
import pandas as pd
import geopandas as gpd
from pathlib import Path

# Find repo root
REPO_ROOT = Path.cwd().parent
print(f"Repo root: {REPO_ROOT}")

REPORT_ROOT = REPO_ROOT / "report"

RESULTS_ROOT = REPO_ROOT / "results"

FIGSIZE = (20,18)
DPI = 100
GENERATE_PLOTS = False
# Out:
# Repo root: /Users/jedrek/Documents/Studium Volkswirschaftslehre/4. Semester/DEDA Project/DEDA_LLM_Spatial_Hotelling

# %%
agents = pd.read_parquet(RESULTS_ROOT / "runs" / "20260528_194531_9faf0df2" / "agents.parquet")
aggregate = pd.read_parquet(RESULTS_ROOT / "runs" / "20260528_194531_9faf0df2" / "aggregate.parquet")
index = pd.read_csv(RESULTS_ROOT / "index.csv")
supermarkets =

# %%
agents
# Out:
#           run_id  period agent_id     price  effort      demand       profit  \
# 0       9faf0df2       0        0  1.000000     7.5   27.675447    -0.449553
# 1       9faf0df2       0        1  1.571429     2.5  735.190552  1152.174438
# 2       9faf0df2       0        2  0.142857     7.5  276.824005    11.421288
# 3       9faf0df2       0        3  0.285714     7.5  541.443115   126.573036
# 4       9faf0df2       0        4  1.857143     2.5  238.467743   439.743652
# ...          ...     ...      ...       ...     ...         ...          ...
# 246995  9faf0df2     499      489  1.428571    10.0  125.284805   128.978287
# 246996  9faf0df2     499      490  0.428571     5.0  921.620483   382.480194
# 246997  9faf0df2     499      491  2.000000     2.5   89.607635   176.090271
# 246998  9faf0df2     499      492  1.714286    10.0  164.118195   231.345490
# 246999  9faf0df2     499      493  1.428571    10.0  298.750671   376.786652
#
#         price_idx  effort_idx
# 0               7           3
# 1              11           1
# 2               1           3
# 3               2           3
# 4              13           1
# ...           ...         ...
# 246995         10           4
# 246996          3           2
# 246997         14           1
# 246998         12           4
# 246999         10           4
#
# [247000 rows x 9 columns]
